# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup


html = urlopen("https://www.aljazeera.com")
print(html)
print("\n\n\n\n-----------------------------------\n\n\n\n\n")
data = html.read()
print(data)
# Out:
# ...
#
#
#
#
# -----------------------------------
#
#
#
#
#
# ...
